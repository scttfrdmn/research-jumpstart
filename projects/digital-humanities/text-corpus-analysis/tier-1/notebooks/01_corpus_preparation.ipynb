# %% [markdown]
# # Multilingual Corpus Preparation
#
# **Duration:** 60 minutes
# **Goal:** Download and prepare 10GB multilingual historical text corpus
#
# This notebook downloads and preprocesses texts in 6 languages:
# - English, French, German, Spanish, Italian, Russian
#
# Data is cached to persistent storage for instant access in future sessions.

# %%
import sys

sys.path.append("..")

from pathlib import Path

print("✓ Imports successful")
print("📦 Starting corpus download (this will take ~60 minutes)...")

# %% [markdown]
# ## Download Multilingual Texts
#
# This cell downloads texts from:
# - Project Gutenberg (English)
# - Wikisource (multilingual)
# - European Literature Archives
#
# **Total size: ~10GB**

# %%
# Placeholder for corpus download
# In production, this would download from actual sources

languages = ["en", "fr", "de", "es", "it", "ru"]
data_dir = Path("../data/raw")
data_dir.mkdir(parents=True, exist_ok=True)

for lang in languages:
    lang_dir = data_dir / lang
    lang_dir.mkdir(exist_ok=True)
    print(f"✓ Created directory for {lang}")

print("\n✓ Corpus structure created")
print("📁 Data saved to: ../data/raw/")
